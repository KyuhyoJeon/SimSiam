# %% [markdown]
# <a href="https://colab.research.google.com/github/KyuhyoJeon/SimSiam/blob/main/SimSiam_PatrickHua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/PatrickHua/SimSiam.git

# %%
import easydict
import os
from datetime import datetime

args = easydict.EasyDict({
    'image_size':224, 
    'learning_rate':0.3,  # origin = 0.2, spijkervet = 3e-4, patrickhua = 0.3
    'momentum':0, 
    'weight_decay':1.5e-6, 
    'batch_size':256, 
    'num_epochs':100, 
    'resnet_version':'resnet18', 
    'optim':'lars', # 'lars', 'adam', 'sgd' 
    'checkpoint_epochs':10, 
    'dataset_dir':'./datasets', 
    'ckpt_dir':'./ckpt', 
    'log_dir':'./log', 
    'num_workers':8, 
    'nodes':1, 
    'gpus':1, 
    'nr':0, 
    'device':'cuda', 
    'eval':True, 
    'dryrun':True, 
    'debug':False
})

args.log_dir = os.path.join(args.log_dir, 'in-progress_'+datetime.now().strftime('%m%d%H%M%S_'))
if not os.path.exists(args.log_dir):
  os.makedirs(args.log_dir)

if args.dryrun:
  args.image_size=32
  args.num_epochs = 10
  args.batch_size = 256
  args.num_workers = 0
  args.dryrun_subset_size = 100
  args.resnet_version = 'resnet18'

if args.debug:
  args.image_size=32
  args.num_epochs = 1
  args.batch_size = 2
  args.num_workers = 0
  args.debug_subset_size = 8
  args.resnet_version = 'resnet18'

tmp_dir = os.path.join(args.ckpt_dir, f"{args.resnet_version}", f"{args.optim}", f"{datetime.now().strftime('%m%d%H')}")
if not os.path.exists(tmp_dir):
  os.makedirs(tmp_dir)

# %%
from torchvision import transforms
from PIL import Image, ImageOps
from torchvision.transforms import GaussianBlur

imagenet_norm = [[0.485, 0.456, 0.406],[0.229, 0.224, 0.225]]

class BYOL_transform: # Table 6 
    def __init__(self, image_size, normalize=imagenet_norm):

        self.transform1 = transforms.Compose([
            transforms.RandomResizedCrop(image_size, scale=(0.08, 1.0), ratio=(3.0/4.0,4.0/3.0), interpolation=Image.BICUBIC),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomApply([transforms.ColorJitter(0.4,0.4,0.2,0.1)], p=0.8),
            transforms.RandomGrayscale(p=0.2),
            transforms.GaussianBlur(kernel_size=image_size//20*2+1, sigma=(0.1, 2.0)), # simclr paper gives the kernel size. Kernel size has to be odd positive number with torchvision
            transforms.ToTensor(),
            transforms.Normalize(*normalize)
        ])
        self.transform2 = transforms.Compose([
            transforms.RandomResizedCrop(image_size, scale=(0.08, 1.0), ratio=(3.0/4.0,4.0/3.0), interpolation=Image.BICUBIC),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomApply([transforms.ColorJitter(0.4,0.4,0.2,0.1)], p=0.8),
            transforms.RandomGrayscale(p=0.2),
            # transforms.RandomApply([GaussianBlur(kernel_size=int(0.1 * image_size))], p=0.1),
            transforms.RandomApply([transforms.GaussianBlur(kernel_size=image_size//20*2+1, sigma=(0.1, 2.0))], p=0.1),
            transforms.RandomApply([Solarization()], p=0.2),
            
            transforms.ToTensor(),
            transforms.Normalize(*normalize)
        ])


    def __call__(self, x):
        x1 = self.transform1(x) 
        x2 = self.transform2(x) 
        return x1, x2


class Transform_single:
    def __init__(self, image_size, train, normalize=imagenet_norm):
        if train == True:
            self.transform = transforms.Compose([
                transforms.RandomResizedCrop(image_size, scale=(0.08, 1.0), ratio=(3.0/4.0,4.0/3.0), interpolation=Image.BICUBIC),
                transforms.RandomHorizontalFlip(),
                transforms.ToTensor(),
                transforms.Normalize(*normalize)
            ])
        else:
            self.transform = transforms.Compose([
                transforms.Resize(int(image_size*(8/7)), interpolation=Image.BICUBIC), # 224 -> 256 
                transforms.CenterCrop(image_size),
                transforms.ToTensor(),
                transforms.Normalize(*normalize)
            ])

    def __call__(self, x):
        return self.transform(x)



class Solarization():
    # ImageFilter
    def __init__(self, threshold=128):
        self.threshold = threshold
    def __call__(self, image):
        return ImageOps.solarize(image, self.threshold)

# %%
import torch
import torchvision

train_set = torchvision.datasets.CIFAR10(
    root=args.dataset_dir, 
    train=True, 
    transform=BYOL_transform(image_size=args.image_size), 
    download=True
)

memory_set = torchvision.datasets.CIFAR10(
    root=args.dataset_dir, 
    train=True, 
    transform=Transform_single(image_size=args.image_size, train=False), 
    download=False
)

test_set = torchvision.datasets.CIFAR10(
    root=args.dataset_dir, 
    train=False,
    transform=Transform_single(image_size=args.image_size, train=False), 
    download=False
)

if args.debug:
  train_set = torch.utils.data.Subset(train_set, range(0, args.debug_subset_size))
  train_set.classes = train_set.dataset.classes
  train_set.targets = train_set.dataset.targets
  memory_set = torch.utils.data.Subset(memory_set, range(0, args.debug_subset_size))
  memory_set.classes = memory_set.dataset.classes
  memory_set.targets = memory_set.dataset.targets
  test_set = torch.utils.data.Subset(test_set, range(0, args.debug_subset_size))
  test_set.classes = test_set.dataset.classes
  test_set.targets = test_set.dataset.targets

train_loader = torch.utils.data.DataLoader(
    train_set, 
    shuffle=True, 
    batch_size=args.batch_size,
    drop_last=True,
    pin_memory=True,
    num_workers=args.num_workers
)

memory_loader = torch.utils.data.DataLoader(
    memory_set, 
    shuffle=False, 
    batch_size=args.batch_size, 
    drop_last=True, 
    pin_memory=True,
    num_workers=args.num_workers
)

test_loader = torch.utils.data.DataLoader(
    test_set, 
    shuffle=False, 
    batch_size=args.batch_size, 
    drop_last=True, 
    pin_memory=True, 
    num_workers=args.num_workers
)
# Out:
# Files already downloaded and verified

# %%
import copy
import random 
from torch import nn 
import torch.nn.functional as F 
from torchvision import transforms 
from math import pi, cos 
from collections import OrderedDict
HPS = dict(
    max_steps=int(1000. * 1281167 / 4096), # 1000 epochs * 1281167 samples / batch size = 100 epochs * N of step/epoch
    # = total_epochs * len(dataloader) 
    mlp_hidden_size=4096,
    projection_size=256,
    base_target_ema=4e-3,
    optimizer_config=dict(
        optimizer_name='lars', 
        beta=0.9, 
        trust_coef=1e-3, 
        weight_decay=1.5e-6,
        exclude_bias_from_adaption=True),
    learning_rate_schedule=dict(
        base_learning_rate=0.2,
        warmup_steps=int(10.0 * 1281167 / 4096), # 10 epochs * N of steps/epoch = 10 epochs * len(dataloader)
        anneal_schedule='cosine'),
    batchnorm_kwargs=dict(
        decay_rate=0.9,
        eps=1e-5), 
    seed=1337,
)

# def loss_fn(x, y, version='simplified'):
    
#     if version == 'original':
#         y = y.detach()
#         x = F.normalize(x, dim=-1, p=2)
#         y = F.normalize(y, dim=-1, p=2)
#         return (2 - 2 * (x * y).sum(dim=-1)).mean()
#     elif version == 'simplified':
#         return (2 - 2 * F.cosine_similarity(x,y.detach(), dim=-1)).mean()
#     else:
#         raise NotImplementedError

def D(p, z, version='simplified'): # negative cosine similarity
    if version == 'original':
        z = z.detach() # stop gradient
        p = F.normalize(p, dim=1) # l2-normalize 
        z = F.normalize(z, dim=1) # l2-normalize 
        return -(p*z).sum(dim=1).mean()

    elif version == 'simplified':# same thing, much faster. Scroll down, speed test in __main__
        return - F.cosine_similarity(p, z.detach(), dim=-1).mean()
    else:
        raise Exception


class MLP(nn.Module):
    def __init__(self, in_dim):
        super().__init__()

        self.layer1 = nn.Sequential(
            nn.Linear(in_dim, HPS['mlp_hidden_size']),
            nn.BatchNorm1d(HPS['mlp_hidden_size'], eps=HPS['batchnorm_kwargs']['eps'], momentum=1-HPS['batchnorm_kwargs']['decay_rate']),
            nn.ReLU(inplace=True)
        )
        self.layer2 = nn.Linear(HPS['mlp_hidden_size'], HPS['projection_size'])

    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        return x

class BYOL(nn.Module):
    def __init__(self, backbone):
        super().__init__()

        self.backbone = backbone
        self.projector = MLP(backbone.output_dim)
        self.online_encoder = nn.Sequential(
            self.backbone,
            self.projector
        )

        self.target_encoder = copy.deepcopy(self.online_encoder)
        self.online_predictor = MLP(HPS['projection_size'])
        # raise NotImplementedError('Please put update_moving_average to training')

    def target_ema(self, k, K, base_ema=HPS['base_target_ema']):
        # tau_base = 0.996 
        # base_ema = 1 - tau_base = 0.996 
        return 1 - base_ema * (cos(pi*k/K)+1)/2 
        # return 1 - (1-self.tau_base) * (cos(pi*k/K)+1)/2 

    @torch.no_grad()
    def update_moving_average(self, global_step, max_steps):
        tau = self.target_ema(global_step, max_steps)
        for online, target in zip(self.online_encoder.parameters(), self.target_encoder.parameters()):
            target.data = tau * target.data + (1 - tau) * online.data
            
    def forward(self, x1, x2):
        f_o, h_o = self.online_encoder, self.online_predictor
        f_t      = self.target_encoder

        z1_o = f_o(x1)
        z2_o = f_o(x2)

        p1_o = h_o(z1_o)
        p2_o = h_o(z2_o)

        with torch.no_grad():
            z1_t = f_t(x1)
            z2_t = f_t(x2)
        
        L = D(p1_o, z2_t) / 2 + D(p2_o, z1_t) / 2 
        return {'loss': L}

# %%
from torchvision import models

resnet = eval(f'models.{args.resnet_version}()')
resnet.output_dim = resnet.fc.in_features
resnet.fc = torch.nn.Identity()

model = BYOL(resnet).to(args.device)
model = torch.nn.DataParallel(model)

# %%
from torch.optim.optimizer import Optimizer 
# comments from the lead author of byol
# 2. + 3. We follow the same implementation as the one used in SimCLR for LARS. This is indeed a bit 
# different from the one described in the LARS paper and the implementation you attached to your email. 
# In particular as in SimCLR we first modify the gradient to include the weight decay (with beta corresponding 
# to self.weight_decay in the SimCLR code) and then adapt the learning rate by dividing by the norm of this 
# sum, this is different from the LARS pseudo code where they divide by the sum of the norm (instead of the 
# norm of the sum as SimCLR and us are doing). This is done in the SimCLR code by first adding the weight 
# decay term to the gradient and then using this sum to perform the adaptation. We also use a term (usually 
# referred to as trust_coefficient but referred as eeta in SimCLR code) set to 1e-3 to multiply the updates 
# of linear layers.
# Note that the logic "if w_norm > 0 and g_norm > 0 else 1.0" is there to tackle numerical instabilities.
# In general we closely followed SimCLR implementation of LARS.
class LARS(Optimizer):
    def __init__(self, 
                 named_modules, 
                 lr,
                 momentum=0.9, # beta? YES
                 trust_coef=1e-3,
                 weight_decay=1.5e-6,
                exclude_bias_from_adaption=True):
        '''byol: As in SimCLR and official implementation of LARS, we exclude bias # and batchnorm weight from the Lars adaptation and weightdecay'''
        defaults = dict(momentum=momentum,
                lr=lr,
                weight_decay=weight_decay,
                 trust_coef=trust_coef)
        parameters = self.exclude_from_model(named_modules, exclude_bias_from_adaption)
        super(LARS, self).__init__(parameters, defaults)

    @torch.no_grad() 
    def step(self):
        for group in self.param_groups: # only 1 group in most cases 
            weight_decay = group['weight_decay']
            momentum = group['momentum']
            lr = group['lr']

            trust_coef = group['trust_coef']
            # print(group['name'])
            # eps = group['eps']
            for p in group['params']:
                # breakpoint()
                if p.grad is None:
                    continue
                global_lr = lr
                velocity = self.state[p].get('velocity', 0)  
                # if name in self.exclude_from_layer_adaptation:
                if self._use_weight_decay(group):
                    p.grad.data += weight_decay * p.data 

                trust_ratio = 1.0 
                if self._do_layer_adaptation(group):
                    w_norm = torch.norm(p.data, p=2)
                    g_norm = torch.norm(p.grad.data, p=2)
                    trust_ratio = trust_coef * w_norm / g_norm if w_norm > 0 and g_norm > 0 else 1.0 
                scaled_lr = global_lr * trust_ratio # trust_ratio is the local_lr 
                next_v = momentum * velocity + scaled_lr * p.grad.data 
                update = next_v
                p.data = p.data - update 


    def _use_weight_decay(self, group):
        return False if group['name'] == 'exclude' else True
    def _do_layer_adaptation(self, group):
        return False if group['name'] == 'exclude' else True

    def exclude_from_model(self, named_modules, exclude_bias_from_adaption=True):
        base = [] 
        exclude = []
        for name, module in named_modules:
            if type(module) in [nn.BatchNorm1d, nn.BatchNorm2d, nn.BatchNorm3d]:
                # if isinstance(module, torch.nn.modules.batchnorm._BatchNorm)
                for name2, param in module.named_parameters():
                    exclude.append(param)
            else:
                for name2, param in module.named_parameters():
                    if name2 == 'bias':
                        exclude.append(param)
                    elif name2 == 'weight':
                        base.append(param)
                    else:
                        pass # non leaf modules 
        return [{
            'name': 'base',
            'params': base
            },{
            'name': 'exclude',
            'params': exclude
        }] if exclude_bias_from_adaption == True else [{
            'name': 'base',
            'params': base+exclude 
        }]

# %%
if args.optim == 'lars':
  optimizer = LARS(
      model.named_modules(), 
      lr=args.learning_rate*args.batch_size/256, 
      momentum=args.momentum, 
      weight_decay=args.weight_decay
  )
elif args.optim == 'adam':
  optimizer = torch.optim.Adam(model.parameters(), lr=args.learning_rate*args.batch_size/256)
elif args.optim == 'sgd':
  optimizer = torch.optim.SGD(model.parameters(), lr=args.learning_rate, momentum=0.9)
else:
  optimizer = LARS(
      model.named_modules(), 
      lr=args.learning_rate*args.batch_size/256, 
      momentum=args.momentum, 
      weight_decay=args.weight_decay
  )

# %%
import numpy as np

class LR_Scheduler(object):
    def __init__(self, optimizer, warmup_epochs, warmup_lr, num_epochs, base_lr, final_lr, iter_per_epoch, constant_predictor_lr=False):
        self.base_lr = base_lr
        self.constant_predictor_lr = constant_predictor_lr
        warmup_iter = iter_per_epoch * warmup_epochs
        warmup_lr_schedule = np.linspace(warmup_lr, base_lr, warmup_iter)
        decay_iter = iter_per_epoch * (num_epochs - warmup_epochs)
        cosine_lr_schedule = final_lr+0.5*(base_lr-final_lr)*(1+np.cos(np.pi*np.arange(decay_iter)/decay_iter))
        
        self.lr_schedule = np.concatenate((warmup_lr_schedule, cosine_lr_schedule))
        self.optimizer = optimizer
        self.iter = 0
        self.current_lr = 0
    def step(self):
        for param_group in self.optimizer.param_groups:

            if self.constant_predictor_lr and param_group['name'] == 'predictor':
                param_group['lr'] = self.base_lr
            else:
                lr = param_group['lr'] = self.lr_schedule[self.iter]
        
        self.iter += 1
        self.current_lr = lr
        return lr
    def get_lr(self):
        return self.current_lr

# %%
lr_scheduler = LR_Scheduler(
    optimizer,
    10, 0*args.batch_size/256, 
    args.num_epochs, args.learning_rate*args.batch_size/256, 0*args.batch_size/256, 
    len(train_loader),
    constant_predictor_lr=True # see the end of section 4.2 predictor
)

# %%
import matplotlib
matplotlib.use('Agg') #https://stackoverflow.com/questions/49921721/runtimeerror-main-thread-is-not-in-main-loop-with-matplotlib-and-flask
import matplotlib.pyplot as plt
from collections import OrderedDict
from torch import Tensor
from torch.utils.tensorboard import SummaryWriter

class Plotter(object):
    def __init__(self):
        self.logger = OrderedDict()
    def update(self, ordered_dict):
        for key, value in ordered_dict.items():
            if isinstance(value, Tensor):
                ordered_dict[key] = value.item()
            if self.logger.get(key) is None:
                self.logger[key] = [value]
            else:
                self.logger[key].append(value)

    def save(self, file, **kwargs):
        fig, axes = plt.subplots(nrows=len(self.logger), ncols=1, figsize=(8,2*len(self.logger)))
        fig.tight_layout()
        for ax, (key, value) in zip(axes, self.logger.items()):
            ax.plot(value)
            ax.set_title(key)

        plt.savefig(file, **kwargs)
        plt.close()

class Logger(object):
    def __init__(self, log_dir, tensorboard=True, matplotlib=True):

        self.reset(log_dir, tensorboard, matplotlib)

    def reset(self, log_dir=None, tensorboard=True, matplotlib=True):

        if log_dir is not None: self.log_dir=log_dir 
        self.writer = SummaryWriter(log_dir=self.log_dir) if tensorboard else None
        self.plotter = Plotter() if matplotlib else None
        self.counter = OrderedDict()

    def update_scalers(self, ordered_dict):

        for key, value in ordered_dict.items():
            if isinstance(value, Tensor):
                ordered_dict[key] = value.item()
            if self.counter.get(key) is None:
                self.counter[key] = 1
            else:
                self.counter[key] += 1

            if self.writer:
                self.writer.add_scalar(key, value, self.counter[key])


        if self.plotter: 
            self.plotter.update(ordered_dict)
            self.plotter.save(os.path.join(self.log_dir, 'plotter.svg'))

# %%
logger = Logger(tensorboard=True, matplotlib=True, log_dir=args.log_dir)

# %%
from tqdm import tqdm

accuracy = 0 
# Start training
global_progress = tqdm(range(0, args.num_epochs), desc=f'Training')
for epoch in global_progress:
    model.train()
    
    local_progress=tqdm(train_loader, desc=f'Epoch {epoch}/{args.num_epochs}', disable=False)
    for idx, ((images1, images2), labels) in enumerate(local_progress):

        model.zero_grad()
        data_dict = model(images1.to(args.device, non_blocking=True), images2.to(args.device, non_blocking=True))
        loss = data_dict['loss'].mean() # ddp
        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        data_dict.update({'lr':lr_scheduler.get_lr()})
        
        local_progress.set_postfix(data_dict)
        logger.update_scalers(data_dict)
    
    epoch_dict = {"epoch":epoch, "accuracy":accuracy}
    global_progress.set_postfix(epoch_dict)
    logger.update_scalers(epoch_dict)

# Save checkpoint
model_path = os.path.join(tmp_dir, f"byol_{datetime.now().strftime('%m%d%H%M%S')}.pth") # datetime.now().strftime('%Y%m%d_%H%M%S')
torch.save({
    'epoch': epoch+1,
    'state_dict':model.module.state_dict()
}, model_path)
print(f"Model saved to {model_path}")
with open(os.path.join(args.log_dir, f"checkpoint_path.txt"), 'w+') as f:
    f.write(f'{model_path}')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
#
#
#
#
#
#
# Epoch 8/10:  85%|████████▍ | 165/195 [03:31<00:38,  1.28s/it, loss=tensor(-0.5662, device='cuda:0', grad_fn=<AddBackward0>), lr=0.265]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  85%|████████▍ | 165/195 [03:32<00:38,  1.28s/it, loss=tensor(-0.5687, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  85%|████████▌ | 166/195 [03:32<00:36,  1.27s/it, loss=tensor(-0.5687, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  85%|████████▌ | 166/195 [03:33<00:36,  1.27s/it, loss=tensor(-0.5676, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  86%|████████▌ | 167/195 [03:34<00:35,  1.27s/it, loss=tensor(-0.5676, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  86%|████████▌ | 167/195 [03:35<00:35,  1.27s/it, loss=tensor(-0.5721, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  86%|████████▌ | 168/195 [03:35<00:34,  1.26s/it, loss=tensor(-0.5721, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  86%|████████▌ | 168/195 [03:36<00:34,  1.26s/it, loss=tensor(-0.5711, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  87%|████████▋ | 169/195 [03:36<00:32,  1.26s/it, loss=tensor(-0.5711, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  87%|████████▋ | 169/195 [03:37<00:32,  1.26s/it, loss=tensor(-0.5712, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  87%|████████▋ | 170/195 [03:37<00:31,  1.25s/it, loss=tensor(-0.5712, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  87%|████████▋ | 170/195 [03:38<00:31,  1.25s/it, loss=tensor(-0.5680, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  88%|████████▊ | 171/195 [03:39<00:31,  1.30s/it, loss=tensor(-0.5680, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  88%|████████▊ | 171/195 [03:40<00:31,  1.30s/it, loss=tensor(-0.5692, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  88%|████████▊ | 172/195 [03:40<00:29,  1.29s/it, loss=tensor(-0.5692, device='cuda:0', grad_fn=<AddBackward0>), lr=0.266]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  88%|████████▊ | 172/195 [03:41<00:29,  1.29s/it, loss=tensor(-0.5737, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  89%|████████▊ | 173/195 [03:41<00:28,  1.29s/it, loss=tensor(-0.5737, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  89%|████████▊ | 173/195 [03:42<00:28,  1.29s/it, loss=tensor(-0.5649, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  89%|████████▉ | 174/195 [03:43<00:26,  1.28s/it, loss=tensor(-0.5649, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  89%|████████▉ | 174/195 [03:43<00:26,  1.28s/it, loss=tensor(-0.5704, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  90%|████████▉ | 175/195 [03:44<00:25,  1.27s/it, loss=tensor(-0.5704, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  90%|████████▉ | 175/195 [03:45<00:25,  1.27s/it, loss=tensor(-0.5698, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  90%|█████████ | 176/195 [03:45<00:24,  1.27s/it, loss=tensor(-0.5698, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  90%|█████████ | 176/195 [03:46<00:24,  1.27s/it, loss=tensor(-0.5728, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  91%|█████████ | 177/195 [03:46<00:22,  1.26s/it, loss=tensor(-0.5728, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  91%|█████████ | 177/195 [03:47<00:22,  1.26s/it, loss=tensor(-0.5701, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  91%|█████████▏| 178/195 [03:48<00:21,  1.27s/it, loss=tensor(-0.5701, device='cuda:0', grad_fn=<AddBackward0>), lr=0.267]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  91%|█████████▏| 178/195 [03:49<00:21,  1.27s/it, loss=tensor(-0.5701, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  92%|█████████▏| 179/195 [03:49<00:20,  1.30s/it, loss=tensor(-0.5701, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  92%|█████████▏| 179/195 [03:50<00:20,  1.30s/it, loss=tensor(-0.5677, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  92%|█████████▏| 180/195 [03:50<00:19,  1.29s/it, loss=tensor(-0.5677, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  92%|█████████▏| 180/195 [03:51<00:19,  1.29s/it, loss=tensor(-0.5687, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  93%|█████████▎| 181/195 [03:52<00:17,  1.28s/it, loss=tensor(-0.5687, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  93%|█████████▎| 181/195 [03:52<00:17,  1.28s/it, loss=tensor(-0.5677, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  93%|█████████▎| 182/195 [03:53<00:16,  1.28s/it, loss=tensor(-0.5677, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  93%|█████████▎| 182/195 [03:54<00:16,  1.28s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  94%|█████████▍| 183/195 [03:54<00:15,  1.27s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  94%|█████████▍| 183/195 [03:55<00:15,  1.27s/it, loss=tensor(-0.5707, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  94%|█████████▍| 184/195 [03:55<00:13,  1.27s/it, loss=tensor(-0.5707, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  94%|█████████▍| 184/195 [03:56<00:13,  1.27s/it, loss=tensor(-0.5682, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  95%|█████████▍| 185/195 [03:57<00:12,  1.28s/it, loss=tensor(-0.5682, device='cuda:0', grad_fn=<AddBackward0>), lr=0.268]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  95%|█████████▍| 185/195 [03:58<00:12,  1.28s/it, loss=tensor(-0.5679, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  95%|█████████▌| 186/195 [03:58<00:11,  1.28s/it, loss=tensor(-0.5679, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  95%|█████████▌| 186/195 [03:59<00:11,  1.28s/it, loss=tensor(-0.5707, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  96%|█████████▌| 187/195 [03:59<00:10,  1.32s/it, loss=tensor(-0.5707, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  96%|█████████▌| 187/195 [04:00<00:10,  1.32s/it, loss=tensor(-0.5641, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  96%|█████████▋| 188/195 [04:01<00:09,  1.30s/it, loss=tensor(-0.5641, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  96%|█████████▋| 188/195 [04:02<00:09,  1.30s/it, loss=tensor(-0.5679, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  97%|█████████▋| 189/195 [04:02<00:07,  1.30s/it, loss=tensor(-0.5679, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  97%|█████████▋| 189/195 [04:03<00:07,  1.30s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  97%|█████████▋| 190/195 [04:03<00:06,  1.29s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  97%|█████████▋| 190/195 [04:04<00:06,  1.29s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  98%|█████████▊| 191/195 [04:04<00:05,  1.28s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.269]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  98%|█████████▊| 191/195 [04:05<00:05,  1.28s/it, loss=tensor(-0.5671, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  98%|█████████▊| 192/195 [04:06<00:03,  1.27s/it, loss=tensor(-0.5671, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  98%|█████████▊| 192/195 [04:07<00:03,  1.27s/it, loss=tensor(-0.5691, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  99%|█████████▉| 193/195 [04:07<00:02,  1.27s/it, loss=tensor(-0.5691, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  99%|█████████▉| 193/195 [04:08<00:02,  1.27s/it, loss=tensor(-0.5675, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  99%|█████████▉| 194/195 [04:08<00:01,  1.27s/it, loss=tensor(-0.5675, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10:  99%|█████████▉| 194/195 [04:09<00:01,  1.27s/it, loss=tensor(-0.5719, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 8/10: 100%|██████████| 195/195 [04:10<00:00,  1.28s/it, loss=tensor(-0.5719, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Training:  80%|████████  | 8/10 [37:19<08:16, 248.18s/it, epoch=8, accuracy=0]
#
#
#
#
#
#
#
#
#
# Training:  90%|█████████ | 9/10 [37:20<04:08, 248.88s/it, epoch=8, accuracy=0]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   0%|          | 0/195 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   0%|          | 0/195 [00:00<?, ?it/s, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   1%|          | 1/195 [00:01<04:05,  1.27s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   1%|          | 1/195 [00:02<04:05,  1.27s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   1%|          | 2/195 [00:02<04:06,  1.28s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   1%|          | 2/195 [00:03<04:06,  1.28s/it, loss=tensor(-0.5676, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   2%|▏         | 3/195 [00:03<04:05,  1.28s/it, loss=tensor(-0.5676, device='cuda:0', grad_fn=<AddBackward0>), lr=0.27]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   2%|▏         | 3/195 [00:04<04:05,  1.28s/it, loss=tensor(-0.5668, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   2%|▏         | 4/195 [00:05<04:02,  1.27s/it, loss=tensor(-0.5668, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   2%|▏         | 4/195 [00:06<04:02,  1.27s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   3%|▎         | 5/195 [00:06<04:01,  1.27s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   3%|▎         | 5/195 [00:07<04:01,  1.27s/it, loss=tensor(-0.5691, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   3%|▎         | 6/195 [00:07<04:00,  1.27s/it, loss=tensor(-0.5691, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   3%|▎         | 6/195 [00:08<04:00,  1.27s/it, loss=tensor(-0.5673, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   4%|▎         | 7/195 [00:09<04:07,  1.32s/it, loss=tensor(-0.5673, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   4%|▎         | 7/195 [00:10<04:07,  1.32s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   4%|▍         | 8/195 [00:10<04:05,  1.31s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   4%|▍         | 8/195 [00:11<04:05,  1.31s/it, loss=tensor(-0.5705, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   5%|▍         | 9/195 [00:11<04:01,  1.30s/it, loss=tensor(-0.5705, device='cuda:0', grad_fn=<AddBackward0>), lr=0.271]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   5%|▍         | 9/195 [00:12<04:01,  1.30s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   5%|▌         | 10/195 [00:12<03:59,  1.29s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   5%|▌         | 10/195 [00:13<03:59,  1.29s/it, loss=tensor(-0.5688, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   6%|▌         | 11/195 [00:14<03:59,  1.30s/it, loss=tensor(-0.5688, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   6%|▌         | 11/195 [00:15<03:59,  1.30s/it, loss=tensor(-0.5668, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   6%|▌         | 12/195 [00:15<03:56,  1.29s/it, loss=tensor(-0.5668, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   6%|▌         | 12/195 [00:16<03:56,  1.29s/it, loss=tensor(-0.5694, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   7%|▋         | 13/195 [00:16<03:55,  1.29s/it, loss=tensor(-0.5694, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   7%|▋         | 13/195 [00:17<03:55,  1.29s/it, loss=tensor(-0.5670, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   7%|▋         | 14/195 [00:18<03:54,  1.30s/it, loss=tensor(-0.5670, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   7%|▋         | 14/195 [00:19<03:54,  1.30s/it, loss=tensor(-0.5683, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   8%|▊         | 15/195 [00:19<03:58,  1.32s/it, loss=tensor(-0.5683, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   8%|▊         | 15/195 [00:20<03:58,  1.32s/it, loss=tensor(-0.5711, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   8%|▊         | 16/195 [00:20<03:55,  1.32s/it, loss=tensor(-0.5711, device='cuda:0', grad_fn=<AddBackward0>), lr=0.272]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   8%|▊         | 16/195 [00:21<03:55,  1.32s/it, loss=tensor(-0.5674, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   9%|▊         | 17/195 [00:22<03:52,  1.30s/it, loss=tensor(-0.5674, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   9%|▊         | 17/195 [00:23<03:52,  1.30s/it, loss=tensor(-0.5679, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   9%|▉         | 18/195 [00:23<03:49,  1.30s/it, loss=tensor(-0.5679, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:   9%|▉         | 18/195 [00:24<03:49,  1.30s/it, loss=tensor(-0.5709, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  10%|▉         | 19/195 [00:24<03:46,  1.29s/it, loss=tensor(-0.5709, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  10%|▉         | 19/195 [00:25<03:46,  1.29s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  10%|█         | 20/195 [00:25<03:44,  1.28s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  10%|█         | 20/195 [00:26<03:44,  1.28s/it, loss=tensor(-0.5706, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  11%|█         | 21/195 [00:27<03:41,  1.27s/it, loss=tensor(-0.5706, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  11%|█         | 21/195 [00:28<03:41,  1.27s/it, loss=tensor(-0.5715, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  11%|█▏        | 22/195 [00:28<03:41,  1.28s/it, loss=tensor(-0.5715, device='cuda:0', grad_fn=<AddBackward0>), lr=0.273]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  11%|█▏        | 22/195 [00:29<03:41,  1.28s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  12%|█▏        | 23/195 [00:29<03:46,  1.32s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  12%|█▏        | 23/195 [00:30<03:46,  1.32s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  12%|█▏        | 24/195 [00:31<03:42,  1.30s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  12%|█▏        | 24/195 [00:32<03:42,  1.30s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  13%|█▎        | 25/195 [00:32<03:40,  1.30s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  13%|█▎        | 25/195 [00:33<03:40,  1.30s/it, loss=tensor(-0.5709, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  13%|█▎        | 26/195 [00:33<03:38,  1.29s/it, loss=tensor(-0.5709, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  13%|█▎        | 26/195 [00:34<03:38,  1.29s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  14%|█▍        | 27/195 [00:34<03:37,  1.29s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  14%|█▍        | 27/195 [00:35<03:37,  1.29s/it, loss=tensor(-0.5652, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  14%|█▍        | 28/195 [00:36<03:34,  1.29s/it, loss=tensor(-0.5652, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  14%|█▍        | 28/195 [00:37<03:34,  1.29s/it, loss=tensor(-0.5662, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  15%|█▍        | 29/195 [00:37<03:33,  1.28s/it, loss=tensor(-0.5662, device='cuda:0', grad_fn=<AddBackward0>), lr=0.274]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  15%|█▍        | 29/195 [00:38<03:33,  1.28s/it, loss=tensor(-0.5685, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  15%|█▌        | 30/195 [00:38<03:32,  1.29s/it, loss=tensor(-0.5685, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  15%|█▌        | 30/195 [00:39<03:32,  1.29s/it, loss=tensor(-0.5657, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  16%|█▌        | 31/195 [00:40<03:35,  1.32s/it, loss=tensor(-0.5657, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  16%|█▌        | 31/195 [00:41<03:35,  1.32s/it, loss=tensor(-0.5681, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  16%|█▋        | 32/195 [00:41<03:31,  1.30s/it, loss=tensor(-0.5681, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  16%|█▋        | 32/195 [00:42<03:31,  1.30s/it, loss=tensor(-0.5670, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  17%|█▋        | 33/195 [00:42<03:29,  1.29s/it, loss=tensor(-0.5670, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  17%|█▋        | 33/195 [00:43<03:29,  1.29s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  17%|█▋        | 34/195 [00:43<03:26,  1.28s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  17%|█▋        | 34/195 [00:44<03:26,  1.28s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  18%|█▊        | 35/195 [00:45<03:24,  1.28s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.275]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  18%|█▊        | 35/195 [00:46<03:24,  1.28s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  18%|█▊        | 36/195 [00:46<03:22,  1.27s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  18%|█▊        | 36/195 [00:47<03:22,  1.27s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  19%|█▉        | 37/195 [00:47<03:21,  1.27s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  19%|█▉        | 37/195 [00:48<03:21,  1.27s/it, loss=tensor(-0.5666, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  19%|█▉        | 38/195 [00:49<03:19,  1.27s/it, loss=tensor(-0.5666, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  19%|█▉        | 38/195 [00:49<03:19,  1.27s/it, loss=tensor(-0.5699, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  20%|██        | 39/195 [00:50<03:25,  1.32s/it, loss=tensor(-0.5699, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  20%|██        | 39/195 [00:51<03:25,  1.32s/it, loss=tensor(-0.5686, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  21%|██        | 40/195 [00:51<03:21,  1.30s/it, loss=tensor(-0.5686, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  21%|██        | 40/195 [00:52<03:21,  1.30s/it, loss=tensor(-0.5724, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  21%|██        | 41/195 [00:53<03:18,  1.29s/it, loss=tensor(-0.5724, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  21%|██        | 41/195 [00:53<03:18,  1.29s/it, loss=tensor(-0.5705, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  22%|██▏       | 42/195 [00:54<03:17,  1.29s/it, loss=tensor(-0.5705, device='cuda:0', grad_fn=<AddBackward0>), lr=0.276]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  22%|██▏       | 42/195 [00:55<03:17,  1.29s/it, loss=tensor(-0.5668, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  22%|██▏       | 43/195 [00:55<03:14,  1.28s/it, loss=tensor(-0.5668, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  22%|██▏       | 43/195 [00:56<03:14,  1.28s/it, loss=tensor(-0.5717, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  23%|██▎       | 44/195 [00:56<03:12,  1.28s/it, loss=tensor(-0.5717, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  23%|██▎       | 44/195 [00:57<03:12,  1.28s/it, loss=tensor(-0.5695, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  23%|██▎       | 45/195 [00:58<03:10,  1.27s/it, loss=tensor(-0.5695, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  23%|██▎       | 45/195 [00:58<03:10,  1.27s/it, loss=tensor(-0.5691, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  24%|██▎       | 46/195 [00:59<03:08,  1.27s/it, loss=tensor(-0.5691, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  24%|██▎       | 46/195 [01:00<03:08,  1.27s/it, loss=tensor(-0.5680, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  24%|██▍       | 47/195 [01:00<03:13,  1.31s/it, loss=tensor(-0.5680, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  24%|██▍       | 47/195 [01:01<03:13,  1.31s/it, loss=tensor(-0.5716, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  25%|██▍       | 48/195 [01:02<03:11,  1.30s/it, loss=tensor(-0.5716, device='cuda:0', grad_fn=<AddBackward0>), lr=0.277]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  25%|██▍       | 48/195 [01:02<03:11,  1.30s/it, loss=tensor(-0.5694, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  25%|██▌       | 49/195 [01:03<03:10,  1.30s/it, loss=tensor(-0.5694, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  25%|██▌       | 49/195 [01:04<03:10,  1.30s/it, loss=tensor(-0.5736, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  26%|██▌       | 50/195 [01:04<03:08,  1.30s/it, loss=tensor(-0.5736, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  26%|██▌       | 50/195 [01:05<03:08,  1.30s/it, loss=tensor(-0.5715, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  26%|██▌       | 51/195 [01:05<03:05,  1.29s/it, loss=tensor(-0.5715, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  26%|██▌       | 51/195 [01:06<03:05,  1.29s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  27%|██▋       | 52/195 [01:07<03:02,  1.28s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  27%|██▋       | 52/195 [01:08<03:02,  1.28s/it, loss=tensor(-0.5725, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  27%|██▋       | 53/195 [01:08<03:01,  1.28s/it, loss=tensor(-0.5725, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  27%|██▋       | 53/195 [01:09<03:01,  1.28s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  28%|██▊       | 54/195 [01:09<03:00,  1.28s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  28%|██▊       | 54/195 [01:10<03:00,  1.28s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  28%|██▊       | 55/195 [01:11<03:03,  1.31s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.278]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  28%|██▊       | 55/195 [01:11<03:03,  1.31s/it, loss=tensor(-0.5702, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  29%|██▊       | 56/195 [01:12<03:00,  1.30s/it, loss=tensor(-0.5702, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  29%|██▊       | 56/195 [01:13<03:00,  1.30s/it, loss=tensor(-0.5701, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  29%|██▉       | 57/195 [01:13<02:56,  1.28s/it, loss=tensor(-0.5701, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  29%|██▉       | 57/195 [01:14<02:56,  1.28s/it, loss=tensor(-0.5658, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  30%|██▉       | 58/195 [01:14<02:54,  1.27s/it, loss=tensor(-0.5658, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  30%|██▉       | 58/195 [01:15<02:54,  1.27s/it, loss=tensor(-0.5680, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  30%|███       | 59/195 [01:16<02:52,  1.27s/it, loss=tensor(-0.5680, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  30%|███       | 59/195 [01:17<02:52,  1.27s/it, loss=tensor(-0.5711, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  31%|███       | 60/195 [01:17<02:50,  1.26s/it, loss=tensor(-0.5711, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  31%|███       | 60/195 [01:18<02:50,  1.26s/it, loss=tensor(-0.5700, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  31%|███▏      | 61/195 [01:18<02:49,  1.26s/it, loss=tensor(-0.5700, device='cuda:0', grad_fn=<AddBackward0>), lr=0.279]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  31%|███▏      | 61/195 [01:19<02:49,  1.26s/it, loss=tensor(-0.5699, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  32%|███▏      | 62/195 [01:19<02:48,  1.26s/it, loss=tensor(-0.5699, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  32%|███▏      | 62/195 [01:20<02:48,  1.26s/it, loss=tensor(-0.5700, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  32%|███▏      | 63/195 [01:21<02:53,  1.31s/it, loss=tensor(-0.5700, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  32%|███▏      | 63/195 [01:22<02:53,  1.31s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  33%|███▎      | 64/195 [01:22<02:52,  1.32s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  33%|███▎      | 64/195 [01:23<02:52,  1.32s/it, loss=tensor(-0.5674, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  33%|███▎      | 65/195 [01:23<02:51,  1.32s/it, loss=tensor(-0.5674, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  33%|███▎      | 65/195 [01:24<02:51,  1.32s/it, loss=tensor(-0.5697, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  34%|███▍      | 66/195 [01:25<02:49,  1.31s/it, loss=tensor(-0.5697, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  34%|███▍      | 66/195 [01:26<02:49,  1.31s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  34%|███▍      | 67/195 [01:26<02:46,  1.30s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  34%|███▍      | 67/195 [01:27<02:46,  1.30s/it, loss=tensor(-0.5686, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  35%|███▍      | 68/195 [01:27<02:44,  1.30s/it, loss=tensor(-0.5686, device='cuda:0', grad_fn=<AddBackward0>), lr=0.28]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  35%|███▍      | 68/195 [01:28<02:44,  1.30s/it, loss=tensor(-0.5704, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  35%|███▌      | 69/195 [01:29<02:42,  1.29s/it, loss=tensor(-0.5704, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  35%|███▌      | 69/195 [01:30<02:42,  1.29s/it, loss=tensor(-0.5672, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  36%|███▌      | 70/195 [01:30<02:41,  1.29s/it, loss=tensor(-0.5672, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  36%|███▌      | 70/195 [01:31<02:41,  1.29s/it, loss=tensor(-0.5701, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  36%|███▋      | 71/195 [01:31<02:45,  1.34s/it, loss=tensor(-0.5701, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  36%|███▋      | 71/195 [01:32<02:45,  1.34s/it, loss=tensor(-0.5645, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  37%|███▋      | 72/195 [01:33<02:43,  1.33s/it, loss=tensor(-0.5645, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  37%|███▋      | 72/195 [01:34<02:43,  1.33s/it, loss=tensor(-0.5669, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  37%|███▋      | 73/195 [01:34<02:40,  1.31s/it, loss=tensor(-0.5669, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  37%|███▋      | 73/195 [01:35<02:40,  1.31s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  38%|███▊      | 74/195 [01:35<02:37,  1.31s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.281]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  38%|███▊      | 74/195 [01:36<02:37,  1.31s/it, loss=tensor(-0.5667, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  38%|███▊      | 75/195 [01:36<02:35,  1.30s/it, loss=tensor(-0.5667, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  38%|███▊      | 75/195 [01:37<02:35,  1.30s/it, loss=tensor(-0.5728, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  39%|███▉      | 76/195 [01:38<02:33,  1.29s/it, loss=tensor(-0.5728, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  39%|███▉      | 76/195 [01:39<02:33,  1.29s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  39%|███▉      | 77/195 [01:39<02:31,  1.28s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  39%|███▉      | 77/195 [01:40<02:31,  1.28s/it, loss=tensor(-0.5697, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  40%|████      | 78/195 [01:40<02:30,  1.29s/it, loss=tensor(-0.5697, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  40%|████      | 78/195 [01:41<02:30,  1.29s/it, loss=tensor(-0.5712, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  41%|████      | 79/195 [01:42<02:33,  1.32s/it, loss=tensor(-0.5712, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  41%|████      | 79/195 [01:43<02:33,  1.32s/it, loss=tensor(-0.5657, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  41%|████      | 80/195 [01:43<02:29,  1.30s/it, loss=tensor(-0.5657, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  41%|████      | 80/195 [01:44<02:29,  1.30s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  42%|████▏     | 81/195 [01:44<02:26,  1.29s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.282]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  42%|████▏     | 81/195 [01:45<02:26,  1.29s/it, loss=tensor(-0.5660, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  42%|████▏     | 82/195 [01:45<02:24,  1.28s/it, loss=tensor(-0.5660, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  42%|████▏     | 82/195 [01:46<02:24,  1.28s/it, loss=tensor(-0.5682, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  43%|████▎     | 83/195 [01:47<02:22,  1.28s/it, loss=tensor(-0.5682, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  43%|████▎     | 83/195 [01:48<02:22,  1.28s/it, loss=tensor(-0.5706, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  43%|████▎     | 84/195 [01:48<02:22,  1.28s/it, loss=tensor(-0.5706, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  43%|████▎     | 84/195 [01:49<02:22,  1.28s/it, loss=tensor(-0.5683, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  44%|████▎     | 85/195 [01:49<02:20,  1.28s/it, loss=tensor(-0.5683, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  44%|████▎     | 85/195 [01:50<02:20,  1.28s/it, loss=tensor(-0.5673, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  44%|████▍     | 86/195 [01:51<02:20,  1.29s/it, loss=tensor(-0.5673, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  44%|████▍     | 86/195 [01:52<02:20,  1.29s/it, loss=tensor(-0.5670, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  45%|████▍     | 87/195 [01:52<02:22,  1.32s/it, loss=tensor(-0.5670, device='cuda:0', grad_fn=<AddBackward0>), lr=0.283]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  45%|████▍     | 87/195 [01:53<02:22,  1.32s/it, loss=tensor(-0.5692, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  45%|████▌     | 88/195 [01:53<02:19,  1.31s/it, loss=tensor(-0.5692, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  45%|████▌     | 88/195 [01:54<02:19,  1.31s/it, loss=tensor(-0.5699, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  46%|████▌     | 89/195 [01:55<02:16,  1.29s/it, loss=tensor(-0.5699, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  46%|████▌     | 89/195 [01:55<02:16,  1.29s/it, loss=tensor(-0.5738, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  46%|████▌     | 90/195 [01:56<02:15,  1.29s/it, loss=tensor(-0.5738, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  46%|████▌     | 90/195 [01:57<02:15,  1.29s/it, loss=tensor(-0.5720, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  47%|████▋     | 91/195 [01:57<02:13,  1.28s/it, loss=tensor(-0.5720, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  47%|████▋     | 91/195 [01:58<02:13,  1.28s/it, loss=tensor(-0.5663, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  47%|████▋     | 92/195 [01:58<02:11,  1.27s/it, loss=tensor(-0.5663, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  47%|████▋     | 92/195 [01:59<02:11,  1.27s/it, loss=tensor(-0.5713, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  48%|████▊     | 93/195 [02:00<02:09,  1.27s/it, loss=tensor(-0.5713, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  48%|████▊     | 93/195 [02:01<02:09,  1.27s/it, loss=tensor(-0.5713, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  48%|████▊     | 94/195 [02:01<02:07,  1.27s/it, loss=tensor(-0.5713, device='cuda:0', grad_fn=<AddBackward0>), lr=0.284]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  48%|████▊     | 94/195 [02:02<02:07,  1.27s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  49%|████▊     | 95/195 [02:02<02:10,  1.31s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  49%|████▊     | 95/195 [02:03<02:10,  1.31s/it, loss=tensor(-0.5705, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  49%|████▉     | 96/195 [02:04<02:08,  1.29s/it, loss=tensor(-0.5705, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  49%|████▉     | 96/195 [02:04<02:08,  1.29s/it, loss=tensor(-0.5708, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  50%|████▉     | 97/195 [02:05<02:06,  1.29s/it, loss=tensor(-0.5708, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  50%|████▉     | 97/195 [02:06<02:06,  1.29s/it, loss=tensor(-0.5653, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  50%|█████     | 98/195 [02:06<02:04,  1.29s/it, loss=tensor(-0.5653, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  50%|█████     | 98/195 [02:07<02:04,  1.29s/it, loss=tensor(-0.5666, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  51%|█████     | 99/195 [02:07<02:03,  1.29s/it, loss=tensor(-0.5666, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  51%|█████     | 99/195 [02:08<02:03,  1.29s/it, loss=tensor(-0.5699, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  51%|█████▏    | 100/195 [02:09<02:02,  1.29s/it, loss=tensor(-0.5699, device='cuda:0', grad_fn=<AddBackward0>), lr=0.285]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  51%|█████▏    | 100/195 [02:10<02:02,  1.29s/it, loss=tensor(-0.5667, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  52%|█████▏    | 101/195 [02:10<01:59,  1.27s/it, loss=tensor(-0.5667, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  52%|█████▏    | 101/195 [02:11<01:59,  1.27s/it, loss=tensor(-0.5716, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  52%|█████▏    | 102/195 [02:11<01:58,  1.27s/it, loss=tensor(-0.5716, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  52%|█████▏    | 102/195 [02:12<01:58,  1.27s/it, loss=tensor(-0.5709, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  53%|█████▎    | 103/195 [02:13<01:59,  1.30s/it, loss=tensor(-0.5709, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  53%|█████▎    | 103/195 [02:13<01:59,  1.30s/it, loss=tensor(-0.5686, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  53%|█████▎    | 104/195 [02:14<01:57,  1.30s/it, loss=tensor(-0.5686, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  53%|█████▎    | 104/195 [02:15<01:57,  1.30s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  54%|█████▍    | 105/195 [02:15<01:56,  1.29s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  54%|█████▍    | 105/195 [02:16<01:56,  1.29s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  54%|█████▍    | 106/195 [02:17<01:53,  1.28s/it, loss=tensor(-0.5691, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  55%|█████▍    | 107/195 [02:18<01:52,  1.28s/it, loss=tensor(-0.5691, device='cuda:0', grad_fn=<AddBackward0>), lr=0.286]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  55%|█████▍    | 107/195 [02:19<01:52,  1.28s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  55%|█████▌    | 108/195 [02:19<01:50,  1.27s/it, loss=tensor(-0.5665, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  55%|█████▌    | 108/195 [02:20<01:50,  1.27s/it, loss=tensor(-0.5682, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  56%|█████▌    | 109/195 [02:20<01:49,  1.27s/it, loss=tensor(-0.5682, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  56%|█████▌    | 109/195 [02:21<01:49,  1.27s/it, loss=tensor(-0.5644, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  56%|█████▋    | 110/195 [02:21<01:47,  1.26s/it, loss=tensor(-0.5644, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  56%|█████▋    | 110/195 [02:22<01:47,  1.26s/it, loss=tensor(-0.5705, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  57%|█████▋    | 111/195 [02:23<01:49,  1.30s/it, loss=tensor(-0.5705, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  57%|█████▋    | 111/195 [02:24<01:49,  1.30s/it, loss=tensor(-0.5673, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  57%|█████▋    | 112/195 [02:24<01:46,  1.28s/it, loss=tensor(-0.5673, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  57%|█████▋    | 112/195 [02:25<01:46,  1.28s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  58%|█████▊    | 113/195 [02:25<01:44,  1.27s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.287]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  58%|█████▊    | 113/195 [02:26<01:44,  1.27s/it, loss=tensor(-0.5695, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  58%|█████▊    | 114/195 [02:27<01:42,  1.26s/it, loss=tensor(-0.5695, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  58%|█████▊    | 114/195 [02:27<01:42,  1.26s/it, loss=tensor(-0.5667, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  59%|█████▉    | 115/195 [02:28<01:40,  1.26s/it, loss=tensor(-0.5667, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  59%|█████▉    | 115/195 [02:29<01:40,  1.26s/it, loss=tensor(-0.5667, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  59%|█████▉    | 116/195 [02:29<01:40,  1.27s/it, loss=tensor(-0.5667, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  59%|█████▉    | 116/195 [02:30<01:40,  1.27s/it, loss=tensor(-0.5732, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  60%|██████    | 117/195 [02:30<01:37,  1.25s/it, loss=tensor(-0.5732, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  60%|██████    | 117/195 [02:31<01:37,  1.25s/it, loss=tensor(-0.5706, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  61%|██████    | 118/195 [02:32<01:36,  1.26s/it, loss=tensor(-0.5706, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  61%|██████    | 118/195 [02:32<01:36,  1.26s/it, loss=tensor(-0.5727, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  61%|██████    | 119/195 [02:33<01:38,  1.30s/it, loss=tensor(-0.5727, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  61%|██████    | 119/195 [02:34<01:38,  1.30s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  62%|██████▏   | 120/195 [02:34<01:36,  1.28s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.288]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  62%|██████▏   | 120/195 [02:35<01:36,  1.28s/it, loss=tensor(-0.5673, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  62%|██████▏   | 121/195 [02:36<01:35,  1.28s/it, loss=tensor(-0.5673, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  62%|██████▏   | 121/195 [02:36<01:35,  1.28s/it, loss=tensor(-0.5719, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  63%|██████▎   | 122/195 [02:37<01:33,  1.28s/it, loss=tensor(-0.5719, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  63%|██████▎   | 122/195 [02:38<01:33,  1.28s/it, loss=tensor(-0.5717, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  63%|██████▎   | 123/195 [02:38<01:31,  1.27s/it, loss=tensor(-0.5717, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  63%|██████▎   | 123/195 [02:39<01:31,  1.27s/it, loss=tensor(-0.5691, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  64%|██████▎   | 124/195 [02:39<01:30,  1.27s/it, loss=tensor(-0.5691, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  64%|██████▎   | 124/195 [02:40<01:30,  1.27s/it, loss=tensor(-0.5700, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  64%|██████▍   | 125/195 [02:41<01:29,  1.28s/it, loss=tensor(-0.5700, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  64%|██████▍   | 125/195 [02:41<01:29,  1.28s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  65%|██████▍   | 126/195 [02:42<01:27,  1.27s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.289]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  65%|██████▍   | 126/195 [02:43<01:27,  1.27s/it, loss=tensor(-0.5639, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  65%|██████▌   | 127/195 [02:43<01:29,  1.31s/it, loss=tensor(-0.5639, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  65%|██████▌   | 127/195 [02:44<01:29,  1.31s/it, loss=tensor(-0.5735, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  66%|██████▌   | 128/195 [02:45<01:26,  1.30s/it, loss=tensor(-0.5735, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  66%|██████▌   | 128/195 [02:45<01:26,  1.30s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  66%|██████▌   | 129/195 [02:46<01:24,  1.29s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  66%|██████▌   | 129/195 [02:47<01:24,  1.29s/it, loss=tensor(-0.5692, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  67%|██████▋   | 130/195 [02:47<01:22,  1.28s/it, loss=tensor(-0.5692, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  67%|██████▋   | 130/195 [02:48<01:22,  1.28s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  67%|██████▋   | 131/195 [02:48<01:21,  1.27s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  67%|██████▋   | 131/195 [02:49<01:21,  1.27s/it, loss=tensor(-0.5711, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  68%|██████▊   | 132/195 [02:50<01:20,  1.28s/it, loss=tensor(-0.5711, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  68%|██████▊   | 132/195 [02:50<01:20,  1.28s/it, loss=tensor(-0.5702, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  68%|██████▊   | 133/195 [02:51<01:18,  1.27s/it, loss=tensor(-0.5702, device='cuda:0', grad_fn=<AddBackward0>), lr=0.29]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  68%|██████▊   | 133/195 [02:52<01:18,  1.27s/it, loss=tensor(-0.5707, device='cuda:0', grad_fn=<AddBackward0>), lr=0.291]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  69%|██████▊   | 134/195 [02:52<01:17,  1.27s/it, loss=tensor(-0.5707, device='cuda:0', grad_fn=<AddBackward0>), lr=0.291]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  69%|██████▊   | 134/195 [02:53<01:17,  1.27s/it, loss=tensor(-0.5702, device='cuda:0', grad_fn=<AddBackward0>), lr=0.291]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  69%|██████▉   | 135/195 [02:54<01:19,  1.32s/it, loss=tensor(-0.5702, device='cuda:0', grad_fn=<AddBackward0>), lr=0.291]
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  72%|███████▏  | 141/195 [03:02<01:09,  1.29s/it, loss=tensor(-0.5708, device='cuda:0', grad_fn=<AddBackward0>), lr=0.292]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  73%|███████▎  | 142/195 [03:02<01:07,  1.28s/it, loss=tensor(-0.5708, device='cuda:0', grad_fn=<AddBackward0>), lr=0.292]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  73%|███████▎  | 142/195 [03:03<01:07,  1.28s/it, loss=tensor(-0.5729, device='cuda:0', grad_fn=<AddBackward0>), lr=0.292]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  73%|███████▎  | 143/195 [03:04<01:08,  1.32s/it, loss=tensor(-0.5729, device='cuda:0', grad_fn=<AddBackward0>), lr=0.292]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  73%|███████▎  | 143/195 [03:05<01:08,  1.32s/it, loss=tensor(-0.5708, device='cuda:0', grad_fn=<AddBackward0>), lr=0.292]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  74%|███████▍  | 144/195 [03:05<01:06,  1.29s/it, loss=tensor(-0.5708, device='cuda:0', grad_fn=<AddBackward0>), lr=0.292]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  74%|███████▍  | 144/195 [03:06<01:06,  1.29s/it, loss=tensor(-0.5671, device='cuda:0', grad_fn=<AddBackward0>), lr=0.292]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  74%|███████▍  | 145/195 [03:06<01:04,  1.29s/it, loss=tensor(-0.5671, device='cuda:0', grad_fn=<AddBackward0>), lr=0.292]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  74%|███████▍  | 145/195 [03:07<01:04,  1.29s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.292]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  75%|███████▍  | 146/195 [03:08<01:02,  1.28s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.292]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  75%|███████▍  | 146/195 [03:09<01:02,  1.28s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  75%|███████▌  | 147/195 [03:09<01:01,  1.28s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  75%|███████▌  | 147/195 [03:10<01:01,  1.28s/it, loss=tensor(-0.5708, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  76%|███████▌  | 148/195 [03:10<00:59,  1.27s/it, loss=tensor(-0.5708, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  76%|███████▌  | 148/195 [03:11<00:59,  1.27s/it, loss=tensor(-0.5696, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  76%|███████▋  | 149/195 [03:11<00:58,  1.27s/it, loss=tensor(-0.5696, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  76%|███████▋  | 149/195 [03:12<00:58,  1.27s/it, loss=tensor(-0.5690, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  77%|███████▋  | 150/195 [03:13<00:57,  1.28s/it, loss=tensor(-0.5690, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  77%|███████▋  | 150/195 [03:14<00:57,  1.28s/it, loss=tensor(-0.5662, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  77%|███████▋  | 151/195 [03:14<00:58,  1.32s/it, loss=tensor(-0.5662, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  77%|███████▋  | 151/195 [03:15<00:58,  1.32s/it, loss=tensor(-0.5682, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  78%|███████▊  | 152/195 [03:15<00:56,  1.31s/it, loss=tensor(-0.5682, device='cuda:0', grad_fn=<AddBackward0>), lr=0.293]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  78%|███████▊  | 152/195 [03:16<00:56,  1.31s/it, loss=tensor(-0.5697, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  78%|███████▊  | 153/195 [03:17<00:54,  1.30s/it, loss=tensor(-0.5697, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  78%|███████▊  | 153/195 [03:18<00:54,  1.30s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  79%|███████▉  | 154/195 [03:18<00:52,  1.29s/it, loss=tensor(-0.5703, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  79%|███████▉  | 154/195 [03:19<00:52,  1.29s/it, loss=tensor(-0.5680, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  79%|███████▉  | 155/195 [03:19<00:51,  1.29s/it, loss=tensor(-0.5680, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  79%|███████▉  | 155/195 [03:20<00:51,  1.29s/it, loss=tensor(-0.5681, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  80%|████████  | 156/195 [03:21<00:50,  1.30s/it, loss=tensor(-0.5681, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  80%|████████  | 156/195 [03:21<00:50,  1.30s/it, loss=tensor(-0.5644, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  81%|████████  | 157/195 [03:22<00:49,  1.29s/it, loss=tensor(-0.5644, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  81%|████████  | 157/195 [03:23<00:49,  1.29s/it, loss=tensor(-0.5683, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  81%|████████  | 158/195 [03:23<00:47,  1.28s/it, loss=tensor(-0.5683, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  81%|████████  | 158/195 [03:24<00:47,  1.28s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  82%|████████▏ | 159/195 [03:25<00:47,  1.32s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.294]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  82%|████████▏ | 159/195 [03:25<00:47,  1.32s/it, loss=tensor(-0.5718, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  82%|████████▏ | 160/195 [03:26<00:45,  1.30s/it, loss=tensor(-0.5718, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  82%|████████▏ | 160/195 [03:27<00:45,  1.30s/it, loss=tensor(-0.5675, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  83%|████████▎ | 161/195 [03:27<00:44,  1.30s/it, loss=tensor(-0.5675, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  83%|████████▎ | 161/195 [03:28<00:44,  1.30s/it, loss=tensor(-0.5727, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  83%|████████▎ | 162/195 [03:28<00:42,  1.29s/it, loss=tensor(-0.5727, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  83%|████████▎ | 162/195 [03:29<00:42,  1.29s/it, loss=tensor(-0.5698, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  84%|████████▎ | 163/195 [03:30<00:41,  1.29s/it, loss=tensor(-0.5698, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  84%|████████▎ | 163/195 [03:31<00:41,  1.29s/it, loss=tensor(-0.5705, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  84%|████████▍ | 164/195 [03:31<00:39,  1.29s/it, loss=tensor(-0.5705, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  84%|████████▍ | 164/195 [03:32<00:39,  1.29s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  85%|████████▍ | 165/195 [03:32<00:38,  1.29s/it, loss=tensor(-0.5689, device='cuda:0', grad_fn=<AddBackward0>), lr=0.295]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  85%|████████▍ | 165/195 [03:33<00:38,  1.29s/it, loss=tensor(-0.5713, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  85%|████████▌ | 166/195 [03:33<00:37,  1.28s/it, loss=tensor(-0.5713, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  85%|████████▌ | 166/195 [03:34<00:37,  1.28s/it, loss=tensor(-0.5688, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  86%|████████▌ | 167/195 [03:35<00:36,  1.32s/it, loss=tensor(-0.5688, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  86%|████████▌ | 167/195 [03:36<00:36,  1.32s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  86%|████████▌ | 168/195 [03:36<00:35,  1.31s/it, loss=tensor(-0.5684, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  86%|████████▌ | 168/195 [03:37<00:35,  1.31s/it, loss=tensor(-0.5700, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  87%|████████▋ | 169/195 [03:37<00:33,  1.30s/it, loss=tensor(-0.5700, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  87%|████████▋ | 169/195 [03:38<00:33,  1.30s/it, loss=tensor(-0.5656, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  87%|████████▋ | 170/195 [03:39<00:32,  1.30s/it, loss=tensor(-0.5656, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  87%|████████▋ | 170/195 [03:40<00:32,  1.30s/it, loss=tensor(-0.5677, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  88%|████████▊ | 171/195 [03:40<00:30,  1.29s/it, loss=tensor(-0.5677, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  88%|████████▊ | 171/195 [03:41<00:30,  1.29s/it, loss=tensor(-0.5688, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  88%|████████▊ | 172/195 [03:41<00:29,  1.28s/it, loss=tensor(-0.5688, device='cuda:0', grad_fn=<AddBackward0>), lr=0.296]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  88%|████████▊ | 172/195 [03:42<00:29,  1.28s/it, loss=tensor(-0.5692, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  89%|████████▊ | 173/195 [03:43<00:28,  1.29s/it, loss=tensor(-0.5692, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  89%|████████▊ | 173/195 [03:43<00:28,  1.29s/it, loss=tensor(-0.5695, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  89%|████████▉ | 174/195 [03:44<00:26,  1.28s/it, loss=tensor(-0.5695, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  89%|████████▉ | 174/195 [03:45<00:26,  1.28s/it, loss=tensor(-0.5686, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  90%|████████▉ | 175/195 [03:45<00:26,  1.33s/it, loss=tensor(-0.5686, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  90%|████████▉ | 175/195 [03:46<00:26,  1.33s/it, loss=tensor(-0.5718, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  90%|█████████ | 176/195 [03:47<00:24,  1.31s/it, loss=tensor(-0.5718, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  90%|█████████ | 176/195 [03:47<00:24,  1.31s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  91%|█████████ | 177/195 [03:48<00:23,  1.30s/it, loss=tensor(-0.5678, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  91%|█████████ | 177/195 [03:49<00:23,  1.30s/it, loss=tensor(-0.5664, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  91%|█████████▏| 178/195 [03:49<00:21,  1.29s/it, loss=tensor(-0.5664, device='cuda:0', grad_fn=<AddBackward0>), lr=0.297]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  91%|█████████▏| 178/195 [03:50<00:21,  1.29s/it, loss=tensor(-0.5671, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  92%|█████████▏| 179/195 [03:50<00:20,  1.28s/it, loss=tensor(-0.5671, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  92%|█████████▏| 179/195 [03:51<00:20,  1.28s/it, loss=tensor(-0.5698, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  92%|█████████▏| 180/195 [03:52<00:19,  1.29s/it, loss=tensor(-0.5698, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  92%|█████████▏| 180/195 [03:53<00:19,  1.29s/it, loss=tensor(-0.5683, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  93%|█████████▎| 181/195 [03:53<00:17,  1.28s/it, loss=tensor(-0.5683, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  93%|█████████▎| 181/195 [03:54<00:17,  1.28s/it, loss=tensor(-0.5730, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  93%|█████████▎| 182/195 [03:54<00:16,  1.29s/it, loss=tensor(-0.5730, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  93%|█████████▎| 182/195 [03:55<00:16,  1.29s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  94%|█████████▍| 183/195 [03:56<00:15,  1.32s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  94%|█████████▍| 183/195 [03:57<00:15,  1.32s/it, loss=tensor(-0.5701, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  94%|█████████▍| 184/195 [03:57<00:14,  1.31s/it, loss=tensor(-0.5701, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  94%|█████████▍| 184/195 [03:58<00:14,  1.31s/it, loss=tensor(-0.5662, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  95%|█████████▍| 185/195 [03:58<00:12,  1.29s/it, loss=tensor(-0.5662, device='cuda:0', grad_fn=<AddBackward0>), lr=0.298]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  95%|█████████▍| 185/195 [03:59<00:12,  1.29s/it, loss=tensor(-0.5666, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  95%|█████████▌| 186/195 [03:59<00:11,  1.28s/it, loss=tensor(-0.5666, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  95%|█████████▌| 186/195 [04:00<00:11,  1.28s/it, loss=tensor(-0.5716, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  96%|█████████▌| 187/195 [04:01<00:10,  1.29s/it, loss=tensor(-0.5716, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  96%|█████████▌| 187/195 [04:02<00:10,  1.29s/it, loss=tensor(-0.5697, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  96%|█████████▋| 188/195 [04:02<00:09,  1.29s/it, loss=tensor(-0.5697, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  96%|█████████▋| 188/195 [04:03<00:09,  1.29s/it, loss=tensor(-0.5692, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  97%|█████████▋| 189/195 [04:03<00:07,  1.28s/it, loss=tensor(-0.5692, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  97%|█████████▋| 189/195 [04:04<00:07,  1.28s/it, loss=tensor(-0.5699, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  97%|█████████▋| 190/195 [04:05<00:06,  1.28s/it, loss=tensor(-0.5699, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  97%|█████████▋| 190/195 [04:05<00:06,  1.28s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  98%|█████████▊| 191/195 [04:06<00:05,  1.31s/it, loss=tensor(-0.5693, device='cuda:0', grad_fn=<AddBackward0>), lr=0.299]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  98%|█████████▊| 191/195 [04:07<00:05,  1.31s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.3]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  98%|█████████▊| 192/195 [04:07<00:03,  1.31s/it, loss=tensor(-0.5714, device='cuda:0', grad_fn=<AddBackward0>), lr=0.3]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  98%|█████████▊| 192/195 [04:08<00:03,  1.31s/it, loss=tensor(-0.5711, device='cuda:0', grad_fn=<AddBackward0>), lr=0.3]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  99%|█████████▉| 193/195 [04:08<00:02,  1.30s/it, loss=tensor(-0.5711, device='cuda:0', grad_fn=<AddBackward0>), lr=0.3]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  99%|█████████▉| 193/195 [04:09<00:02,  1.30s/it, loss=tensor(-0.5713, device='cuda:0', grad_fn=<AddBackward0>), lr=0.3]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  99%|█████████▉| 194/195 [04:10<00:01,  1.30s/it, loss=tensor(-0.5713, device='cuda:0', grad_fn=<AddBackward0>), lr=0.3]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10:  99%|█████████▉| 194/195 [04:11<00:01,  1.30s/it, loss=tensor(-0.5707, device='cuda:0', grad_fn=<AddBackward0>), lr=0.3]
#
#
#
#
#
#
#
#
#
#
# Epoch 9/10: 100%|██████████| 195/195 [04:11<00:00,  1.29s/it, loss=tensor(-0.5707, device='cuda:0', grad_fn=<AddBackward0>), lr=0.3]
#
#
#
#
#
#
#
#
#
#
# Training:  90%|█████████ | 9/10 [41:31<04:08, 248.88s/it, epoch=9, accuracy=0]
#
#
#
#
#
#
#
#
#
# Training: 100%|██████████| 10/10 [41:32<00:00, 249.21s/it, epoch=9, accuracy=0]
# Model saved to ./ckpt/resnet18/lars/021408/byol_0214091941.pth

# %%
def knn_monitor(net, memory_data_loader, test_data_loader, epoch, k=200, t=0.1, hide_progress=False):
    net.eval()
    classes = len(memory_data_loader.dataset.classes)
    total_top1, total_top5, total_num, feature_bank = 0.0, 0.0, 0, []
    with torch.no_grad():
        # generate feature bank
        for data, target in tqdm(memory_data_loader, desc='Feature extracting', leave=False, disable=hide_progress):
            feature = net(data.cuda(non_blocking=True))
            feature = F.normalize(feature, dim=1)
            feature_bank.append(feature)
        # [D, N]
        feature_bank = torch.cat(feature_bank, dim=0).t().contiguous()
        # [N]
        feature_labels = torch.tensor(memory_data_loader.dataset.targets, device=feature_bank.device)
        # loop test data to predict the label by weighted knn search
        test_bar = tqdm(test_data_loader, desc='kNN', disable=hide_progress)
        for data, target in test_bar:
            data, target = data.cuda(non_blocking=True), target.cuda(non_blocking=True)
            feature = net(data)
            feature = F.normalize(feature, dim=1)
            
            pred_labels = knn_predict(feature, feature_bank, feature_labels, classes, k, t)

            total_num += data.size(0)
            total_top1 += (pred_labels[:, 0] == target).float().sum().item()
            test_bar.set_postfix({'Accuracy':total_top1 / total_num * 100})
    return total_top1 / total_num * 100

# knn monitor as in InstDisc https://arxiv.org/abs/1805.01978
# implementation follows http://github.com/zhirongw/lemniscate.pytorch and https://github.com/leftthomas/SimCLR
def knn_predict(feature, feature_bank, feature_labels, classes, knn_k, knn_t):
    # compute cos similarity between each feature vector and feature bank ---> [B, N]
    sim_matrix = torch.mm(feature, feature_bank)
    # [B, K]
    sim_weight, sim_indices = sim_matrix.topk(k=knn_k, dim=-1)
    # [B, K]
    sim_labels = torch.gather(feature_labels.expand(feature.size(0), -1), dim=-1, index=sim_indices)
    sim_weight = (sim_weight / knn_t).exp()

    # counts for each class
    one_hot_label = torch.zeros(feature.size(0) * knn_k, classes, device=sim_labels.device)
    # [B*K, C]
    one_hot_label = one_hot_label.scatter(dim=-1, index=sim_labels.view(-1, 1), value=1.0)
    # weighted score ---> [B, C]
    pred_scores = torch.sum(one_hot_label.view(feature.size(0), -1, classes) * sim_weight.unsqueeze(dim=-1), dim=1)

    pred_labels = pred_scores.argsort(dim=-1, descending=True)
    return pred_labels

# %%
accuracy = knn_monitor(model.module.backbone, memory_loader, test_loader, args.device, k=min(200, len(memory_loader.dataset)), hide_progress=False)
print('Accuracy:', accuracy)
# Out:
# Feature extracting:   0%|          | 0/195 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:   1%|          | 1/195 [00:00<00:19,  9.77it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:   1%|          | 2/195 [00:00<00:19,  9.76it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:   2%|▏         | 4/195 [00:00<00:18, 10.31it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:   3%|▎         | 6/195 [00:00<00:17, 11.00it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:   4%|▍         | 8/195 [00:00<00:16, 11.38it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:   5%|▌         | 10/195 [00:00<00:15, 11.87it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:   6%|▌         | 12/195 [00:00<00:14, 12.29it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:   7%|▋         | 14/195 [00:01<00:14, 12.62it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:   8%|▊         | 16/195 [00:01<00:14, 12.68it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:   9%|▉         | 18/195 [00:01<00:13, 12.76it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  10%|█         | 20/195 [00:01<00:13, 12.78it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  11%|█▏        | 22/195 [00:01<00:13, 12.75it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  12%|█▏        | 24/195 [00:01<00:13, 12.47it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  13%|█▎        | 26/195 [00:02<00:13, 12.55it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  14%|█▍        | 28/195 [00:02<00:13, 12.56it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  15%|█▌        | 30/195 [00:02<00:13, 12.24it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  16%|█▋        | 32/195 [00:02<00:13, 12.31it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  17%|█▋        | 34/195 [00:02<00:12, 12.57it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  18%|█▊        | 36/195 [00:02<00:12, 12.34it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  19%|█▉        | 38/195 [00:03<00:12, 12.46it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  21%|██        | 40/195 [00:03<00:12, 12.74it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  22%|██▏       | 42/195 [00:03<00:12, 12.72it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  23%|██▎       | 44/195 [00:03<00:11, 12.81it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  24%|██▎       | 46/195 [00:03<00:11, 12.88it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  25%|██▍       | 48/195 [00:03<00:11, 13.04it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  26%|██▌       | 50/195 [00:03<00:11, 12.93it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  27%|██▋       | 52/195 [00:04<00:11, 12.86it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  28%|██▊       | 54/195 [00:04<00:10, 12.90it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  29%|██▊       | 56/195 [00:04<00:11, 12.54it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  30%|██▉       | 58/195 [00:04<00:10, 12.49it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  31%|███       | 60/195 [00:04<00:10, 12.58it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  32%|███▏      | 62/195 [00:04<00:10, 12.70it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  33%|███▎      | 64/195 [00:05<00:10, 12.59it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  34%|███▍      | 66/195 [00:05<00:10, 12.65it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  35%|███▍      | 68/195 [00:05<00:10, 12.51it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  36%|███▌      | 70/195 [00:05<00:09, 12.59it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  37%|███▋      | 72/195 [00:05<00:09, 12.69it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  38%|███▊      | 74/195 [00:05<00:09, 12.87it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  39%|███▉      | 76/195 [00:06<00:09, 12.73it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  40%|████      | 78/195 [00:06<00:09, 12.74it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  41%|████      | 80/195 [00:06<00:08, 12.79it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  42%|████▏     | 82/195 [00:06<00:08, 12.82it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  43%|████▎     | 84/195 [00:06<00:08, 12.72it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  44%|████▍     | 86/195 [00:06<00:08, 12.83it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  45%|████▌     | 88/195 [00:06<00:08, 12.64it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  46%|████▌     | 90/195 [00:07<00:08, 12.79it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  47%|████▋     | 92/195 [00:07<00:08, 12.52it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  48%|████▊     | 94/195 [00:07<00:08, 12.13it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  49%|████▉     | 96/195 [00:07<00:08, 12.17it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  50%|█████     | 98/195 [00:07<00:07, 12.35it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  51%|█████▏    | 100/195 [00:07<00:07, 12.44it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  52%|█████▏    | 102/195 [00:08<00:07, 12.46it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  53%|█████▎    | 104/195 [00:08<00:07, 12.52it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  54%|█████▍    | 106/195 [00:08<00:07, 12.63it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  55%|█████▌    | 108/195 [00:08<00:06, 12.58it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  56%|█████▋    | 110/195 [00:08<00:06, 12.65it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  57%|█████▋    | 112/195 [00:08<00:06, 12.59it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  58%|█████▊    | 114/195 [00:09<00:06, 12.71it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  59%|█████▉    | 116/195 [00:09<00:06, 12.95it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  61%|██████    | 118/195 [00:09<00:05, 12.98it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  62%|██████▏   | 120/195 [00:09<00:05, 13.08it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  63%|██████▎   | 122/195 [00:09<00:05, 12.74it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  64%|██████▎   | 124/195 [00:09<00:05, 12.75it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  65%|██████▍   | 126/195 [00:09<00:05, 12.74it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  66%|██████▌   | 128/195 [00:10<00:05, 12.75it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  67%|██████▋   | 130/195 [00:10<00:05, 12.88it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  68%|██████▊   | 132/195 [00:10<00:04, 12.90it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  69%|██████▊   | 134/195 [00:10<00:04, 12.95it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  70%|██████▉   | 136/195 [00:10<00:04, 12.89it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  71%|███████   | 138/195 [00:10<00:04, 13.00it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  72%|███████▏  | 140/195 [00:11<00:04, 12.84it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  73%|███████▎  | 142/195 [00:11<00:04, 13.06it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  74%|███████▍  | 144/195 [00:11<00:03, 13.06it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  75%|███████▍  | 146/195 [00:11<00:03, 12.91it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  76%|███████▌  | 148/195 [00:11<00:03, 12.38it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  77%|███████▋  | 150/195 [00:11<00:03, 12.51it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  78%|███████▊  | 152/195 [00:12<00:03, 12.60it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  79%|███████▉  | 154/195 [00:12<00:03, 12.78it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  80%|████████  | 156/195 [00:12<00:03, 12.88it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  81%|████████  | 158/195 [00:12<00:02, 12.88it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  82%|████████▏ | 160/195 [00:12<00:02, 12.74it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  83%|████████▎ | 162/195 [00:12<00:02, 12.44it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  84%|████████▍ | 164/195 [00:12<00:02, 12.58it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  85%|████████▌ | 166/195 [00:13<00:02, 12.53it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  86%|████████▌ | 168/195 [00:13<00:02, 12.63it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  87%|████████▋ | 170/195 [00:13<00:01, 12.63it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  88%|████████▊ | 172/195 [00:13<00:01, 12.71it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  89%|████████▉ | 174/195 [00:13<00:01, 12.70it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  90%|█████████ | 176/195 [00:13<00:01, 12.96it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  91%|█████████▏| 178/195 [00:14<00:01, 13.03it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  92%|█████████▏| 180/195 [00:14<00:01, 13.24it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  93%|█████████▎| 182/195 [00:14<00:01, 12.96it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  94%|█████████▍| 184/195 [00:14<00:00, 13.15it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  95%|█████████▌| 186/195 [00:14<00:00, 13.08it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  96%|█████████▋| 188/195 [00:14<00:00, 13.20it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  97%|█████████▋| 190/195 [00:14<00:00, 13.15it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  98%|█████████▊| 192/195 [00:15<00:00, 13.40it/s]
#
#
#
#
#
#
#
#
#
# Feature extracting:  99%|█████████▉| 194/195 [00:15<00:00, 13.45it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kNN:   0%|          | 0/39 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# kNN:   0%|          | 0/39 [00:00<?, ?it/s, Accuracy=38.3]
#
#
#
#
#
#
#
#
#
# kNN:   3%|▎         | 1/39 [00:00<00:04,  8.48it/s, Accuracy=38.3]
#
#
#
#
#
#
#
#
#
# kNN:   3%|▎         | 1/39 [00:00<00:04,  8.48it/s, Accuracy=35.7]
#
#
#
#
#
#
#
#
#
# kNN:   5%|▌         | 2/39 [00:00<00:04,  8.32it/s, Accuracy=35.7]
#
#
#
#
#
#
#
#
#
# kNN:   5%|▌         | 2/39 [00:00<00:04,  8.32it/s, Accuracy=35.4]
#
#
#
#
#
#
#
#
#
# kNN:   8%|▊         | 3/39 [00:00<00:04,  8.23it/s, Accuracy=35.4]
#
#
#
#
#
#
#
#
#
# kNN:   8%|▊         | 3/39 [00:00<00:04,  8.23it/s, Accuracy=34.5]
#
#
#
#
#
#
#
#
#
# kNN:  10%|█         | 4/39 [00:00<00:04,  8.23it/s, Accuracy=34.5]
#
#
#
#
#
#
#
#
#
# kNN:  10%|█         | 4/39 [00:00<00:04,  8.23it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  13%|█▎        | 5/39 [00:00<00:04,  8.26it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  13%|█▎        | 5/39 [00:00<00:04,  8.26it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  15%|█▌        | 6/39 [00:00<00:04,  8.11it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  15%|█▌        | 6/39 [00:00<00:04,  8.11it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  18%|█▊        | 7/39 [00:00<00:03,  8.15it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  18%|█▊        | 7/39 [00:00<00:03,  8.15it/s, Accuracy=32.4]
#
#
#
#
#
#
#
#
#
# kNN:  21%|██        | 8/39 [00:00<00:03,  8.19it/s, Accuracy=32.4]
#
#
#
#
#
#
#
#
#
# kNN:  21%|██        | 8/39 [00:01<00:03,  8.19it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  23%|██▎       | 9/39 [00:01<00:03,  8.15it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  23%|██▎       | 9/39 [00:01<00:03,  8.15it/s, Accuracy=32.5]
#
#
#
#
#
#
#
#
#
# kNN:  26%|██▌       | 10/39 [00:01<00:03,  8.22it/s, Accuracy=32.5]
#
#
#
#
#
#
#
#
#
# kNN:  26%|██▌       | 10/39 [00:01<00:03,  8.22it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  28%|██▊       | 11/39 [00:01<00:03,  8.15it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  28%|██▊       | 11/39 [00:01<00:03,  8.15it/s, Accuracy=31.9]
#
#
#
#
#
#
#
#
#
# kNN:  31%|███       | 12/39 [00:01<00:03,  8.25it/s, Accuracy=31.9]
#
#
#
#
#
#
#
#
#
# kNN:  31%|███       | 12/39 [00:01<00:03,  8.25it/s, Accuracy=31.6]
#
#
#
#
#
#
#
#
#
# kNN:  33%|███▎      | 13/39 [00:01<00:03,  8.25it/s, Accuracy=31.6]
#
#
#
#
#
#
#
#
#
# kNN:  33%|███▎      | 13/39 [00:01<00:03,  8.25it/s, Accuracy=31.6]
#
#
#
#
#
#
#
#
#
# kNN:  36%|███▌      | 14/39 [00:01<00:03,  8.18it/s, Accuracy=31.6]
#
#
#
#
#
#
#
#
#
# kNN:  36%|███▌      | 14/39 [00:01<00:03,  8.18it/s, Accuracy=31.8]
#
#
#
#
#
#
#
#
#
# kNN:  38%|███▊      | 15/39 [00:01<00:02,  8.12it/s, Accuracy=31.8]
#
#
#
#
#
#
#
#
#
# kNN:  38%|███▊      | 15/39 [00:01<00:02,  8.12it/s, Accuracy=31.8]
#
#
#
#
#
#
#
#
#
# kNN:  41%|████      | 16/39 [00:01<00:02,  8.21it/s, Accuracy=31.8]
#
#
#
#
#
#
#
#
#
# kNN:  41%|████      | 16/39 [00:02<00:02,  8.21it/s, Accuracy=31.9]
#
#
#
#
#
#
#
#
#
# kNN:  44%|████▎     | 17/39 [00:02<00:02,  8.11it/s, Accuracy=31.9]
#
#
#
#
#
#
#
#
#
# kNN:  44%|████▎     | 17/39 [00:02<00:02,  8.11it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  46%|████▌     | 18/39 [00:02<00:02,  8.17it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  46%|████▌     | 18/39 [00:02<00:02,  8.17it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  49%|████▊     | 19/39 [00:02<00:02,  8.20it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  49%|████▊     | 19/39 [00:02<00:02,  8.20it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  51%|█████▏    | 20/39 [00:02<00:02,  8.24it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  51%|█████▏    | 20/39 [00:02<00:02,  8.24it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  54%|█████▍    | 21/39 [00:02<00:02,  8.05it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  54%|█████▍    | 21/39 [00:02<00:02,  8.05it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  56%|█████▋    | 22/39 [00:02<00:02,  8.07it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  56%|█████▋    | 22/39 [00:02<00:02,  8.07it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  59%|█████▉    | 23/39 [00:02<00:01,  8.17it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  59%|█████▉    | 23/39 [00:02<00:01,  8.17it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  62%|██████▏   | 24/39 [00:02<00:01,  8.24it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  62%|██████▏   | 24/39 [00:03<00:01,  8.24it/s, Accuracy=32.2]
#
#
#
#
#
#
#
#
#
# kNN:  64%|██████▍   | 25/39 [00:03<00:01,  8.15it/s, Accuracy=32.2]
#
#
#
#
#
#
#
#
#
# kNN:  64%|██████▍   | 25/39 [00:03<00:01,  8.15it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  67%|██████▋   | 26/39 [00:03<00:01,  8.15it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  67%|██████▋   | 26/39 [00:03<00:01,  8.15it/s, Accuracy=32.2]
#
#
#
#
#
#
#
#
#
# kNN:  69%|██████▉   | 27/39 [00:03<00:01,  8.17it/s, Accuracy=32.2]
#
#
#
#
#
#
#
#
#
# kNN:  69%|██████▉   | 27/39 [00:03<00:01,  8.17it/s, Accuracy=32.2]
#
#
#
#
#
#
#
#
#
# kNN:  72%|███████▏  | 28/39 [00:03<00:01,  8.14it/s, Accuracy=32.2]
#
#
#
#
#
#
#
#
#
# kNN:  72%|███████▏  | 28/39 [00:03<00:01,  8.14it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  74%|███████▍  | 29/39 [00:03<00:01,  8.09it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  74%|███████▍  | 29/39 [00:03<00:01,  8.09it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  77%|███████▋  | 30/39 [00:03<00:01,  8.07it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  77%|███████▋  | 30/39 [00:03<00:01,  8.07it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  79%|███████▉  | 31/39 [00:03<00:00,  8.07it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  79%|███████▉  | 31/39 [00:03<00:00,  8.07it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  82%|████████▏ | 32/39 [00:03<00:00,  8.06it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  82%|████████▏ | 32/39 [00:04<00:00,  8.06it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  85%|████████▍ | 33/39 [00:04<00:00,  8.10it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  85%|████████▍ | 33/39 [00:04<00:00,  8.10it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  87%|████████▋ | 34/39 [00:04<00:00,  8.17it/s, Accuracy=32]
#
#
#
#
#
#
#
#
#
# kNN:  87%|████████▋ | 34/39 [00:04<00:00,  8.17it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  90%|████████▉ | 35/39 [00:04<00:00,  8.12it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN:  90%|████████▉ | 35/39 [00:04<00:00,  8.12it/s, Accuracy=32.2]
#
#
#
#
#
#
#
#
#
# kNN:  92%|█████████▏| 36/39 [00:04<00:00,  7.90it/s, Accuracy=32.2]
#
#
#
#
#
#
#
#
#
# kNN:  92%|█████████▏| 36/39 [00:04<00:00,  7.90it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  95%|█████████▍| 37/39 [00:04<00:00,  7.88it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  95%|█████████▍| 37/39 [00:04<00:00,  7.88it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  97%|█████████▋| 38/39 [00:04<00:00,  7.71it/s, Accuracy=32.3]
#
#
#
#
#
#
#
#
#
# kNN:  97%|█████████▋| 38/39 [00:04<00:00,  7.71it/s, Accuracy=32.1]
#
#
#
#
#
#
#
#
#
# kNN: 100%|██████████| 39/39 [00:04<00:00,  8.09it/s, Accuracy=32.1]

# %%
class AverageMeter():
    """Computes and stores the average and current value"""
    def __init__(self, name, fmt=':f'):
        self.name = name
        self.fmt = fmt
        self.log = []
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def reset(self):
        self.log.append(self.avg)
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = '{name} {val' + self.fmt + '} ({avg' + self.fmt + '})'
        return fmtstr.format(**self.__dict__)

def linear_eval(args, eval_from):

    train_loader = torch.utils.data.DataLoader(
        dataset=torchvision.datasets.CIFAR10(
            args.dataset_dir, 
            train=True, 
            transform=Transform_single(args.image_size, train=True)
        ),
        batch_size=args.batch_size,
        shuffle=True,
        drop_last=True,
        pin_memory=True,
        num_workers=args.num_workers
    )
    test_loader = torch.utils.data.DataLoader(
        dataset=torchvision.datasets.CIFAR10(
            args.dataset_dir, 
            train=False,
            transform=Transform_single(args.image_size, train=False)
        ),
        batch_size=args.batch_size,
        shuffle=False,
        drop_last=True,
        pin_memory=True,
        num_workers=args.num_workers
    )


    model = eval(f'models.{args.resnet_version}()')
    model.output_dim = model.fc.in_features
    model.fc = torch.nn.Identity()
    classifier = nn.Linear(in_features=model.output_dim, out_features=10, bias=True).to(args.device)

    assert eval_from is not None
    save_dict = torch.load(eval_from, map_location='cuda')
    msg = model.load_state_dict({k[9:]:v for k, v in save_dict['state_dict'].items() if k.startswith('backbone.')}, strict=True)
    
    # print(msg)
    model = model.to(args.device)
    model = torch.nn.DataParallel(model)

    # if torch.cuda.device_count() > 1: classifier = torch.nn.SyncBatchNorm.convert_sync_batchnorm(classifier)
    classifier = torch.nn.DataParallel(classifier)
    # define optimizer
    optimizer = torch.optim.SGD(model.parameters(), lr=30*args.batch_size/256, momentum=0.9, weight_decay=0)

    # define lr scheduler
    lr_scheduler = LR_Scheduler(
        optimizer,
        0, 0*args.batch_size/256, 
        30, 30*args.batch_size/256, 0*args.batch_size/256, 
        len(train_loader),
    )

    loss_meter = AverageMeter(name='Loss')
    acc_meter = AverageMeter(name='Accuracy')

    # Start training
    global_progress = tqdm(range(0, 30), desc=f'Evaluating')
    for epoch in global_progress:
        loss_meter.reset()
        model.eval()
        classifier.train()
        local_progress = tqdm(train_loader, desc=f'Epoch {epoch}/{30}', disable=True)
        
        for idx, (images, labels) in enumerate(local_progress):

            classifier.zero_grad()
            with torch.no_grad():
                feature = model(images.to(args.device))

            preds = classifier(feature)

            loss = F.cross_entropy(preds, labels.to(args.device))

            loss.backward()
            optimizer.step()
            loss_meter.update(loss.item())
            lr = lr_scheduler.step()
            local_progress.set_postfix({'lr':lr, "loss":loss_meter.val, 'loss_avg':loss_meter.avg})

    classifier.eval()
    correct, total = 0, 0
    acc_meter.reset()
    for idx, (images, labels) in enumerate(test_loader):
        with torch.no_grad():
            feature = model(images.to(args.device))
            preds = classifier(feature).argmax(dim=1)
            correct = (preds == labels.to(args.device)).sum().item()
            acc_meter.update(correct/preds.shape[0])
    print(f'Accuracy = {acc_meter.avg*100:.2f}')

# %%
if args.eval is not False:
    linear_eval(args, model_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-6dd85087800f> in <module>()
#       1 if args.eval is not False:
# ----> 2     linear_eval(args, model_path)
#
# NameError: name 'linear_eval' is not defined
